# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings

import scipy.io as sio

from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
cosmo.age(1)

import seaborn as sns
import pandas as pd
from astropy.io import fits

sns.set(font_scale=2)
sns.set_style("whitegrid")

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d

import statsmodels.api as sm
lowess = sm.nonparametric.lowess

# %%
warnings.filterwarnings('ignore')

candels_cat_z1 = np.loadtxt('catalogs/CANDELS_GDSS_workshop_z1.dat')

# subtracting 1 from the ID for python indexing
cat_z1_ids = candels_cat_z1[0:,0] - 1
cat_z1_z = candels_cat_z1[0:,1]

print(str(cat_z1_z.shape[0])+' galaxies in the z~1 catalog.')
# Out:
# 371 galaxies in the z~1 catalog.

# %% [markdown]
# so there's some sets of fits that use the CANDELS IR data: AGNfitter, Magphys, Bagpipes, Cigale, Prospector?
#
# ## here's the rundown of what i have
#
#
#                  no IR               | with IR             |
#  CODE            no AGN  | with AGN  | no AGN  | with AGN  |
#
# 0. AGNfitter  |          |           |         | yes       |
# 1. Prospector |  yes(?)  |           | yes     | yes       |
# 2. MAGPHYS    |  yes     | yes       | yes     | yes       |
# 3. Bagpipes   |  yes(?)  |           | yes(?)  |           |
# 4. Cigale
#
#               |          |           |         |           |

# %%
z1_cat_mass_dict = {'Prospector (no IR, no AGN)':prospector_mass_z1, 
                    'Prospector (w/IR, no AGN)':prospector_mass_z1_IR,
                    'Prospector (w/IR, w/AGN)':prospector_mass_z1_IR_AGN,
                    'MAGPHYS (no IR, no AGN)': magphys_mass_z1,
                    'MAGPHYS (no IR, w/AGN)': magphys_mass_z1_wagn,
                    'MAGPHYS (w/IR, no AGN)': magphys_ir_mass,
                    'MAGPHYS (w/IR, w/AGN)': magphys_ir_mass_AGN,
                    'AGNFitter': agnfitter_mass,
                    'BAGPIPES (no IR)':bagpipes_mass_z1,
                    'BAGPIPES (w/IR)':bagpipes_IR_mass,
                    'CIGALE (no IR, no AGN)': cigale_mass,
                    'CIGALE (w/IR, no AGN)': cigale_ir_mass,
                    'CIGALE (w/IR, w/AGN)': cigale_ir_agn_mass
                   }
z1_cat_mass = pd.DataFrame(data=z1_cat_mass_dict)

z1_cat_mass[z1_cat_mass < 7] = np.nan


z1_cat_sfr_dict = {'Prospector (no IR, no AGN)':prospector_sfr_z1, 
                    'Prospector (w/IR, no AGN)':prospector_sfr_z1_IR,
                    'Prospector (w/IR, w/AGN)':prospector_sfr_z1_IR_AGN,
                    'MAGPHYS (no IR, no AGN)': magphys_sfr_z1,
                    'MAGPHYS (no IR, w/AGN)': magphys_sfr_z1_wagn,
                    'MAGPHYS (w/IR, no AGN)': magphys_ir_sfr,
                    'MAGPHYS (w/IR, w/AGN)': magphys_ir_sfr_AGN,
                    'AGNFitter': agnfitter_sfr,
                    'BAGPIPES (no IR)':bagpipes_sfr_z1,
                    'BAGPIPES (w/IR)':bagpipes_IR_sfr,
                    'CIGALE (no IR, no AGN)': cigale_sfr,
                    'CIGALE (w/IR, no AGN)': cigale_ir_sfr,
                    'CIGALE (w/IR, w/AGN)': cigale_ir_agn_sfr
                   }
z1_cat_sfr = pd.DataFrame(data=z1_cat_sfr_dict)

z1_cat_sfr[z1_cat_sfr < -3] = np.nan


z1_cat_av_dict = {'Prospector (no IR, no AGN)':prospector_Av_z1, 
                    'Prospector (w/IR, no AGN)':prospector_Av_z1_IR,
                    'Prospector (w/IR, w/AGN)':prospector_Av_z1_IR_AGN,
                    'MAGPHYS (no IR, no AGN)': magphys_Av_z1,
                    'MAGPHYS (no IR, w/AGN)': magphys_Av_z1_wagn,
                    'MAGPHYS (w/IR, no AGN)': magphys_ir_av,
                    'MAGPHYS (w/IR, w/AGN)': magphys_ir_av_AGN,
                    'AGNFitter': agnfitter_av,
                    'BAGPIPES (no IR)':bagpipes_Av_z1,
                    'BAGPIPES (w/IR)':bagpipes_IR_av,
                    'CIGALE (no IR, no AGN)': cigale_Av,
                    'CIGALE (w/IR, no AGN)': cigale_ir_Av,
                    'CIGALE (w/IR, w/AGN)': cigale_ir_agn_Av
                   }
z1_cat_av = pd.DataFrame(data=z1_cat_av_dict)

z1_cat_av[z1_cat_av < 0] = np.nan

# %%
sns.set_style('whitegrid')

plt.figure(figsize=(15,6))
ax = sns.violinplot(data=z1_cat_mass, orient='v',zorder=10)


median_mass_val = np.nanmedian(z1_cat_mass)
plt.plot([-20,20],[median_mass_val,median_mass_val],'k-')
plt.fill_between([-20,20], [median_mass_val+0.3,median_mass_val+0.3], [median_mass_val-0.3,median_mass_val-0.3], alpha=0.5)
ax.set_xticks(np.arange(z1_cat_mass.shape[1])+0.3)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,horizontalalignment='right',position=(1,0))
ax.set_ylabel('log Stellar Mass')
ax.set_title('z=1 sample (371 galaxies)')

plt.show()


plt.figure(figsize=(15,6))
ax = sns.violinplot(data=z1_cat_sfr, orient='v',zorder=10)


median_sfr_val = np.nanmedian(z1_cat_sfr)
plt.plot([-20,20],[median_sfr_val,median_sfr_val],'k-')
plt.fill_between([-20,20], [median_sfr_val+0.3,median_sfr_val+0.3], [median_sfr_val-0.3,median_sfr_val-0.3], alpha=0.5)
ax.set_xticks(np.arange(z1_cat_sfr.shape[1])+0.3)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,horizontalalignment='right',position=(1,0))
ax.set_ylabel('log SFR')
ax.set_title('z=1 sample (371 galaxies)')

plt.show()

sns.set_style('whitegrid')

plt.figure(figsize=(15,6))
ax = sns.violinplot(data=z1_cat_av, orient='v',zorder=10,cut=0)


median_Av_val = np.nanmedian(z1_cat_av)
plt.plot([-20,20],[median_Av_val,median_Av_val],'k-')
plt.fill_between([-20,20], [median_Av_val+0.3,median_Av_val+0.3], [median_Av_val-0.3,median_Av_val-0.3], alpha=0.5)
ax.set_xticks(np.arange(z1_cat_av.shape[1])+0.3)
ax.set_xticklabels(ax.get_xticklabels(),rotation=60,horizontalalignment='right',position=(1,0))
ax.set_ylabel('Av')
ax.set_title('z=1 sample (371 galaxies)')

plt.show()

# %% [markdown]
# # Prospector:

# %%
prospector_cat_z1 = np.genfromtxt('code_outputs/prospector_output_z1.dat',delimiter=',')

prospector_ids_z1 = prospector_cat_z1[0:,0]

prospector_mass_z1 = prospector_cat_z1[0:,1]
prospector_mass_hi_z1 = prospector_cat_z1[0:,1] + prospector_cat_z1[0:,2]
prospector_mass_lo_z1 = prospector_cat_z1[0:,1] - prospector_cat_z1[0:,3]

prospector_sfr_z1 = prospector_cat_z1[0:,4]
prospector_sfr_hi_z1 = prospector_cat_z1[0:,4] + prospector_cat_z1[0:,5]
prospector_sfr_lo_z1 = prospector_cat_z1[0:,4] - prospector_cat_z1[0:,6]

prospector_Av_z1 = prospector_cat_z1[0:,7]
prospector_Av_hi_z1 = prospector_cat_z1[0:,7] + prospector_cat_z1[0:,8]
prospector_Av_lo_z1 = prospector_cat_z1[0:,7] - prospector_cat_z1[0:,9]

# objname,
# logmass,logmass_errup,logmass_errdown,
# logsfr100,logsfr100_errup,logsfr100_errdown,
# logsfr10,logsfr10_errup,logsfr10_errdown,
# mwa,mwa_errup,mwa_errdown,
# av,av_errup,av_errdown

prospector_cat_z1_IR = np.genfromtxt('code_outputs_IR/prospector_output_z1_ir.dat',delimiter=',')

prospector_ids_z1_IR = prospector_cat_z1_IR[0:,0]

prospector_mass_z1_IR = prospector_cat_z1_IR[0:,1]
prospector_mass_hi_z1_IR = prospector_cat_z1_IR[0:,1] + prospector_cat_z1_IR[0:,2]
prospector_mass_lo_z1_IR = prospector_cat_z1_IR[0:,1] - prospector_cat_z1_IR[0:,3]

prospector_sfr_z1_IR = prospector_cat_z1_IR[0:,7]
prospector_sfr_hi_z1_IR = prospector_cat_z1_IR[0:,7] + prospector_cat_z1_IR[0:,8]
prospector_sfr_lo_z1_IR = prospector_cat_z1_IR[0:,7] - prospector_cat_z1_IR[0:,9]

prospector_Av_z1_IR = prospector_cat_z1_IR[0:,13]
prospector_Av_hi_z1_IR = prospector_cat_z1_IR[0:,13] + prospector_cat_z1_IR[0:,14]
prospector_Av_lo_z1_IR = prospector_cat_z1_IR[0:,13] - prospector_cat_z1_IR[0:,15]


prospector_cat_z1_IR_AGN = np.genfromtxt('code_outputs_IR/prospector_output_z1_ir_agn.dat',delimiter=',')

prospector_ids_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,0]

prospector_mass_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,1]
prospector_mass_hi_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,1] + prospector_cat_z1_IR_AGN[0:,2]
prospector_mass_lo_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,1] - prospector_cat_z1_IR_AGN[0:,3]

prospector_sfr_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,7]
prospector_sfr_hi_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,7] + prospector_cat_z1_IR_AGN[0:,8]
prospector_sfr_lo_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,7] - prospector_cat_z1_IR_AGN[0:,9]

prospector_Av_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,13]
prospector_Av_hi_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,13] + prospector_cat_z1_IR_AGN[0:,14]
prospector_Av_lo_z1_IR_AGN = prospector_cat_z1_IR_AGN[0:,13] - prospector_cat_z1_IR_AGN[0:,15]

# %%
print(prospector_mass_z1[0:10])
print(prospector_mass_z1_IR[0:10])
print(prospector_mass_z1_IR_AGN[0:10])
# Out:
# [10.1   9.96 10.36 10.33 11.05  9.56  9.34  9.68  9.38 10.31]
# [10.1   9.4  10.44  9.97 11.07  9.69  9.4   9.68  9.45 10.26]
# [10.    9.14 10.46 10.26 11.09  9.59  9.41  9.74  9.45 10.29]

# %% [markdown]
# # AGNfitter:

# %%
agnfitter_full = fits.open('code_outputs_IR/AGNfitter_CANDELS_z1sample.fits')
agnfitter_full.info()
agnfitter_full[1].header
# Out:
# Filename: code_outputs_IR/AGNfitter_CANDELS_z1sample.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      16   (951,)   uint8
#   1  /Users/Gabriela/Dropbox/AGNinSMGs/AGNfitter_catoutput_CANDELS_z1_...  BinTableHDU     35   369R x 11C   [D, E, E, E, E, E, E, E, E, E, D]
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                   52 / width of table in bytes
# NAXIS2  =                  369 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                   11 / number of columns
# EXTNAME = '/Users/Gabriela/Dropbox/AGNinSMGs/AGNfitter_catoutput_CANDELS_z1_...'
# TTYPE1  = 'ID      '           / label for column 1
# TFORM1  = 'D       '           / format for column 1
# TTYPE2  = 'EBVgal  '           / label for column 2
# TFORM2  = 'E       '           / format for column 2
# TTYPE3  = 'EBVgal-e'           / label for column 3
# TFORM3  = 'E       '           / format for column 3
# TTYPE4  = 'EBVgal+e'           / label for column 4
# TFORM4  = 'E       '           / format for column 4
# TTYPE5  = 'logMstar'           / label for column 5
# TFORM5  = 'E       '           / format for column 5
# TTYPE6  = 'logMstar-e'         / label for column 6
# TFORM6  = 'E       '           / format for column 6
# TTYPE7  = 'logMstar+e'         / label for column 7
# TFORM7  = 'E       '           / format for column 7
# TTYPE8  = 'SFR_opt '           / label for column 8
# TFORM8  = 'E       '           / format for column 8
# TTYPE9  = 'SFR_opt-e'          / label for column 9
# TFORM9  = 'E       '           / format for column 9
# TTYPE10 = 'SFR_opt+e'          / label for column 10
# TFORM10 = 'E       '           / format for column 10
# TTYPE11 = 'AGNfraction[1-10um]' / label for column 11
# TFORM11 = 'D       '           / format for column 11
# TCOMM11 = '(pow(10,$56)/(pow(10,$56)+pow(10,$53)+pow(10,$59)))'
# DATE-HDU= '2018-08-07T18:56:00' / Date of HDU creation (UTC)
# STILVERS= '3.0-8   '           / Version of STIL software
# STILCLAS= 'uk.ac.starlink.votable.FitsPlusTableWriter' / Author class in STIL so

# %%
agnfitter_cat = agnfitter_full[1].data

agnfitter_ids = np.zeros((len(cat_z1_ids),))

agnfitter_mass = np.zeros((len(cat_z1_ids),))
agnfitter_mass_lo = np.zeros((len(cat_z1_ids),))
agnfitter_mass_hi = np.zeros((len(cat_z1_ids),))

agnfitter_sfr = np.zeros((len(cat_z1_ids),))
agnfitter_sfr_lo = np.zeros((len(cat_z1_ids),))
agnfitter_sfr_hi = np.zeros((len(cat_z1_ids),))

agnfitter_av = np.zeros((len(cat_z1_ids)))
agnfitter_av_lo = np.zeros((len(cat_z1_ids)))
agnfitter_av_hi = np.zeros((len(cat_z1_ids)))

#for i in range(agnfitter_ids.shape[0]):
for i in range(369):
    
    temp = agnfitter_full[1].data[i][0]
    id_index = np.argmin(np.abs(temp - cat_z1_ids+1))
    agnfitter_ids[id_index] = temp
    
    agnfitter_mass[id_index] = agnfitter_full[1].data[i][4]
    agnfitter_sfr[id_index] = np.log10(agnfitter_full[1].data[i][7])
    agnfitter_av[id_index] = agnfitter_full[1].data[i][1] * 4.05

print(cat_z1_ids[0:10]+1)
print(agnfitter_ids[0:10])
# Out:
# [ 21.  25.  40.  58.  79. 143. 170. 190. 239. 267.]
# [ 21.  25.  40.  58.  79. 143. 170. 190. 239. 267.]

# %%
plt.scatter(agnfitter_mass[agnfitter_ids>0], agnfitter_sfr[agnfitter_ids>0],c=agnfitter_av[agnfitter_ids>0],cmap='magma')
plt.show()

# %%
agnfitter_full.close()

# %% [markdown]
# # MAGPHYS

# %%
magphys_cat = np.genfromtxt('code_outputs/magphys_output.dat')
print(magphys_cat.shape)

# ID_0    
#tau_v16_0   tau_v50_0   tau_v84_0   - 3
#sSFR16_0   sSFR50_0   sSFR84_0    -6
#Mstar16_0   Mstar50_0   Mstar84_0    -9
#Ldust16_0   Ldust50_0   Ldust84_0    -12
#Mdust16_0   Mdust50_0   Mdust84_0    -15
#SFR16_0   SFR50_0   SFR84_0    -18
#age_M16_0   age_M50_0   age_M84_0  -21  
#A_V16_0   A_V50_0   A_V84_0    -24
#Tdust16_0   Tdust50_0   Tdust84_0  -27  
#tau_v16_agn   tau_v50_agn   tau_v84_agn    -30
#sSFR16_agn   sSFR50_agn   sSFR84_agn    - 33
#Mstar16_agn   Mstar50_agn   Mstar84_agn    -36
#Ldust16_agn   Ldust50_agn   Ldust84_agn    - 39
#Mdust16_agn   Mdust50_agn   Mdust84_agn    - 42
#SFR16_agn   SFR50_agn   SFR84_agn    - 45
#age_M16_agn   age_M50_agn   age_M84_agn   - 48
#A_V16_agn   A_V50_agn   A_V84_agn    - 51
#Tdust16_agn   Tdust50_agn   Tdust84_agn   - 54 
#agnf16_agn   agnf50_agn   agnf84_agn    - 57
#Ldustsf16_agn   Ldustsf50_agn   Ldustsf84_agn    -60
#Ldustagn16_agn   Ldustagn50_agn   Ldustagn84_agn  

magphys_id_full = magphys_cat[0:,0]

magphys_mass_full = magphys_cat[0:,8]
magphys_mass_full_low = magphys_cat[0:,7]
magphys_mass_full_high = magphys_cat[0:,9]

magphys_sfr_full = magphys_cat[0:,16]
magphys_sfr_full_low = magphys_cat[0:,17]
magphys_sfr_full_high = magphys_cat[0:,18]

magphys_Av_full = magphys_cat[0:,23]
magphys_Av_full_low = magphys_cat[0:,22]
magphys_Av_full_high = magphys_cat[0:,24]

magphys_mass_full_wagn = magphys_cat[0:,35]
magphys_mass_full_low_wagn = magphys_cat[0:,34]
magphys_mass_full_high_wagn = magphys_cat[0:,36]

magphys_sfr_full_wagn = magphys_cat[0:,44]
magphys_sfr_full_low_wagn = magphys_cat[0:,43]
magphys_sfr_full_high_wagn = magphys_cat[0:,45]

magphys_Av_full_wagn = magphys_cat[0:,50]
magphys_Av_full_low_wagn = magphys_cat[0:,49]
magphys_Av_full_high_wagn = magphys_cat[0:,51]

magphys_ids_z1 = np.zeros((len(cat_z1_ids),))

magphys_mass_z1 = np.zeros((len(cat_z1_ids),))
magphys_mass_lo_z1 = np.zeros((len(cat_z1_ids),))
magphys_mass_hi_z1 = np.zeros((len(cat_z1_ids),))

magphys_sfr_z1 = np.zeros((len(cat_z1_ids),))
magphys_sfr_lo_z1 = np.zeros((len(cat_z1_ids),))
magphys_sfr_hi_z1 = np.zeros((len(cat_z1_ids),))

magphys_Av_z1 = np.zeros((len(cat_z1_ids),))
magphys_Av_lo_z1 = np.zeros((len(cat_z1_ids),))
magphys_Av_hi_z1 = np.zeros((len(cat_z1_ids),))


magphys_mass_z1_wagn = np.zeros((len(cat_z1_ids),))
magphys_mass_lo_z1_wagn = np.zeros((len(cat_z1_ids),))
magphys_mass_hi_z1_wagn = np.zeros((len(cat_z1_ids),))

magphys_sfr_z1_wagn = np.zeros((len(cat_z1_ids),))
magphys_sfr_lo_z1_wagn = np.zeros((len(cat_z1_ids),))
magphys_sfr_hi_z1_wagn = np.zeros((len(cat_z1_ids),))

magphys_Av_z1_wagn = np.zeros((len(cat_z1_ids),))
magphys_Av_lo_z1_wagn = np.zeros((len(cat_z1_ids),))
magphys_Av_hi_z1_wagn = np.zeros((len(cat_z1_ids),))

for i in range(len(cat_z1_ids)):
    #print(len(magphys_id_full[magphys_id_full == candels_z1_ids[i]+1]))
    if len(magphys_id_full[magphys_id_full == cat_z1_ids[i]+1]) == 1:
        magphys_ids_z1[i] = magphys_id_full[magphys_id_full == cat_z1_ids[i]+1]
        
        magphys_mass_z1[i] = magphys_mass_full[magphys_id_full == cat_z1_ids[i]+1]
        magphys_mass_lo_z1[i] = magphys_mass_full_low[magphys_id_full == cat_z1_ids[i]+1]
        magphys_mass_hi_z1[i] = magphys_mass_full_high[magphys_id_full == cat_z1_ids[i]+1]
        
        magphys_sfr_z1[i] = magphys_sfr_full[magphys_id_full == cat_z1_ids[i]+1]
        magphys_sfr_lo_z1[i] = magphys_sfr_full_low[magphys_id_full == cat_z1_ids[i]+1]
        magphys_sfr_hi_z1[i] = magphys_sfr_full_high[magphys_id_full == cat_z1_ids[i]+1]
        
        magphys_Av_z1[i] = magphys_Av_full[magphys_id_full == cat_z1_ids[i]+1]
        magphys_Av_lo_z1[i] = magphys_Av_full_low[magphys_id_full == cat_z1_ids[i]+1]
        magphys_Av_hi_z1[i] = magphys_Av_full_high[magphys_id_full == cat_z1_ids[i]+1]
        
        magphys_mass_z1_wagn[i] = magphys_mass_full_wagn[magphys_id_full == cat_z1_ids[i]+1]
        magphys_mass_lo_z1_wagn[i] = magphys_mass_full_low_wagn[magphys_id_full == cat_z1_ids[i]+1]
        magphys_mass_hi_z1_wagn[i] = magphys_mass_full_high_wagn[magphys_id_full == cat_z1_ids[i]+1]
        
        magphys_sfr_z1_wagn[i] = magphys_sfr_full_wagn[magphys_id_full == cat_z1_ids[i]+1]
        magphys_sfr_lo_z1_wagn[i] = magphys_sfr_full_low_wagn[magphys_id_full == cat_z1_ids[i]+1]
        magphys_sfr_hi_z1_wagn[i] = magphys_sfr_full_high_wagn[magphys_id_full == cat_z1_ids[i]+1]
        
        magphys_Av_z1_wagn[i] = magphys_Av_full_wagn[magphys_id_full == cat_z1_ids[i]+1]
        magphys_Av_lo_z1_wagn[i] = magphys_Av_full_low_wagn[magphys_id_full == cat_z1_ids[i]+1]
        magphys_Av_hi_z1_wagn[i] = magphys_Av_full_high_wagn[magphys_id_full == cat_z1_ids[i]+1]
    else:
        print('id:'+str(cat_z1_ids[i])+' not found. mass set to NaN')
        magphys_mass_z1[i] = np.nan
        magphys_sfr_z1[i] = np.nan
        magphys_mass_z1_wagn[i] = np.nan
        magphys_sfr_z1_wagn[i] = np.nan

print(np.sum(magphys_ids_z1))

# plt.hist(magphys_mass_full)
# plt.show()
# Out:
# (384, 64)
# id:1204.0 not found. mass set to NaN
# id:3630.0 not found. mass set to NaN
# id:7194.0 not found. mass set to NaN
# id:9605.0 not found. mass set to NaN
# id:20260.0 not found. mass set to NaN
# id:26721.0 not found. mass set to NaN
# 5322630.0

# %%
magphys_IR_full = fits.open('code_outputs_IR/magphys_output_z1_ir.fits')
magphys_IR_full.info()
magphys_IR_full[1].header
# Out:
# Filename: code_outputs_IR/magphys_output_z1_ir.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      16   (18309,)   uint8
#   1  Joined      BinTableHDU    678   365R x 333C   [9A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, I, E, D, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 9A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, I, I, E, D, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                 1340 / width of table in bytes
# NAXIS2  =                  365 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                  333 / number of columns
# EXTNAME = 'Joined  '           / table name
# TTYPE1  = 'ID_0    '           / label for column 1
# TFORM1  = '9A      '           / format for column 1
# TTYPE2  = 'CTIO_U_0'           / label for column 2
# TFORM2  = 'E       '           / format for column 2
# TTYPE3  = 'VIMOS_U_0'          / label for column 3
# TFORM3  = 'E       '           / format for column 3
# TTYPE4  = 'ACS_F435W_0'        / label for column 4
# TFORM4  = 'E       '           / format for column 4
# TTYPE5  = 'ACS_F606W_0'        / label for column 5
# TFORM5  = 'E       '           / format for column 5
# TTYPE6  = 'ACS_F775W_0'        / label for column 6
# TFORM6  = 'E       '           / format for column 6
# TTYPE7  = 'ACS_F814W_0'        / label for column 7
# TFORM7  = 'E       '           / format for column 7
# TTYPE8  = 'ACS_F850LP_0'       / label for column 8
# TFORM8  = 'E       '           / format for column 8
# TTYPE9  = 'WFC3_F098M_0'       / label for column 9
# TFORM9  = 'E       '           / format for column 9
# TTYPE10 = 'WFC3_F105W_0'       / label for column 10
# TFORM10 = 'E       '           / format for column 10
# TTYPE11 = 'WFC3_F125W_0'       / label for column 11
# TFORM11 = 'E       '           / format for column 11
# TTYPE12 = 'WFC3_F160W_0'       / label for column 12
# TFORM12 = 'E       '           / format for column 12
# TTYPE13 = 'ISAAC_KS_0'         / label for column 13
# TFORM13 = 'E       '           / format for column 13
# TTYPE14 = 'HAWKI_KS_0'         / label for column 14
# TFORM14 = 'E       '           / format for column 14
# TTYPE15 = 'IRAC_CH1_0'         / label for column 15
# TFORM15 = 'E       '           / format for column 15
# TTYPE16 = 'IRAC_CH2_0'         / label for column 16
# TFORM16 = 'E       '           / format for column 16
# TTYPE17 = 'IRAC_CH3_0'         / label for column 17
# TFORM17 = 'E       '           / format for column 17
# TTYPE18 = 'IRAC_CH4_0'         / label for column 18
# TFORM18 = 'E       '           / format for column 18
# TTYPE19 = 'f24_0_1 '           / label for column 19
# TFORM19 = 'E       '           / format for column 19
# TTYPE20 = 'f70_0   '           / label for column 20
# TFORM20 = 'E       '           / format for column 20
# TTYPE21 = 'f100_0  '           / label for column 21
# TFORM21 = 'E       '           / format for column 21
# TTYPE22 = 'f160_0  '           / label for column 22
# TFORM22 = 'E       '           / format for column 22
# TTYPE23 = 'f250_0  '           / label for column 23
# TFORM23 = 'E       '           / format for column 23
# TTYPE24 = 'eCTIO_U_0'          / label for column 24
# TFORM24 = 'E       '           / format for column 24
# TTYPE25 = 'eVIMOS_U_0'         / label for column 25
# TFORM25 = 'E       '           / format for column 25
# TTYPE26 = 'eACS_F435W_0'       / label for column 26
# TFORM26 = 'E       '           / format for column 26
# TTYPE27 = 'eACS_F606W_0'       / label for column 27
# TFORM27 = 'E       '           / format for column 27
# TTYPE28 = 'eACS_F775W_0'       / label for column 28
# TFORM28 = 'E       '           / format for column 28
# TTYPE29 = 'eACS_F814W_0'       / label for column 29
# TFORM29 = 'E       '           / format for column 29
# TTYPE30 = 'eACS_F850LP_0'      / label for column 30
# TFORM30 = 'E       '           / format for column 30
# TTYPE31 = 'eWFC3_F098M_0'      / label for column 31
# TFORM31 = 'E       '           / format for column 31
# TTYPE32 = 'eWFC3_F105W_0'      / label for column 32
# TFORM32 = 'E       '           / format for column 32
# TTYPE33 = 'eWFC3_F125W_0'      / label for column 33
# TFORM33 = 'E       '           / format for column 33
# TTYPE34 = 'eWFC3_F160W_0'      / label for column 34
# TFORM34 = 'E       '           / format for column 34
# TTYPE35 = 'eISAAC_KS_0'        / label for column 35
# TFORM35 = 'E       '           / format for column 35
# TTYPE36 = 'eHAWKI_KS_0'        / label for column 36
# TFORM36 = 'E       '           / format for column 36
# TTYPE37 = 'eIRAC_CH1_0'        / label for column 37
# TFORM37 = 'E       '           / format for column 37
# TTYPE38 = 'eIRAC_CH2_0'        / label for column 38
# TFORM38 = 'E       '           / format for column 38
# TTYPE39 = 'eIRAC_CH3_0'        / label for column 39
# TFORM39 = 'E       '           / format for column 39
# TTYPE40 = 'eIRAC_CH4_0'        / label for column 40
# TFORM40 = 'E       '           / format for column 40
# TTYPE41 = 'ef24_0  '           / label for column 41
# TFORM41 = 'E       '           / format for column 41
# TTYPE42 = 'ef70_0  '           / label for column 42
# TFORM42 = 'E       '           / format for column 42
# TTYPE43 = 'ef100_0 '           / label for column 43
# TFORM43 = 'E       '           / format for column 43
# TTYPE44 = 'ef160_0 '           / label for column 44
# TFORM44 = 'E       '           / format for column 44
# TTYPE45 = 'ef250_0 '           / label for column 45
# TFORM45 = 'E       '           / format for column 45
# TTYPE46 = 'i_sfh_0 '           / label for column 46
# TFORM46 = 'I       '           / format for column 46
# TTYPE47 = 'i_ir_0  '           / label for column 47
# TFORM47 = 'I       '           / format for column 47
# TTYPE48 = 'chi2_0  '           / label for column 48
# TFORM48 = 'E       '           / format for column 48
# TTYPE49 = 'redshift_0'         / label for column 49
# TFORM49 = 'D       '           / format for column 49
# TTYPE50 = 'fmu_SFH_bestfit_0'  / label for column 50
# TFORM50 = 'E       '           / format for column 50
# TTYPE51 = 'fmu_IR_bestfit_0'   / label for column 51
# TFORM51 = 'E       '           / format for column 51
# TTYPE52 = 'mu_bestfit_0'       / label for column 52
# TFORM52 = 'E       '           / format for column 52
# TTYPE53 = 'tauv_bestfit_0'     / label for column 53
# TFORM53 = 'E       '           / format for column 53
# TTYPE54 = 'sSFR_bestfit_0'     / label for column 54
# TFORM54 = 'E       '           / format for column 54
# TTYPE55 = 'Mstar_bestfit_0'    / label for column 55
# TFORM55 = 'E       '           / format for column 55
# TTYPE56 = 'Ldust_bestfit_0'    / label for column 56
# TFORM56 = 'E       '           / format for column 56
# TTYPE57 = 'T_W_BC_bestfit_0'   / label for column 57
# TFORM57 = 'E       '           / format for column 57
# TTYPE58 = 'T_C_ISM_bestfit_0'  / label for column 58
# TFORM58 = 'E       '           / format for column 58
# TTYPE59 = 'xi_C_tot_bestfit_0' / label for column 59
# TFORM59 = 'E       '           / format for column 59
# TTYPE60 = 'xi_PAH_tot_bestfit_0' / label for column 60
# TFORM60 = 'E       '           / format for column 60
# TTYPE61 = 'xi_MIR_tot_bestfit_0' / label for column 61
# TFORM61 = 'E       '           / format for column 61
# TTYPE62 = 'xi_W_tot_bestfit_0' / label for column 62
# TFORM62 = 'E       '           / format for column 62
# TTYPE63 = 'tvism_bestfit_0'    / label for column 63
# TFORM63 = 'E       '           / format for column 63
# TTYPE64 = 'Mdust_bestfit_0'    / label for column 64
# TFORM64 = 'E       '           / format for column 64
# TTYPE65 = 'SFR_bestfit_0'      / label for column 65
# TFORM65 = 'E       '           / format for column 65
# TTYPE66 = 'A_V_bestfit_0'      / label for column 66
# TFORM66 = 'E       '           / format for column 66
# TTYPE67 = 'age_M_bestfit_0'    / label for column 67
# TFORM67 = 'E       '           / format for column 67
# TTYPE68 = 'Tdust_bestfit_0'    / label for column 68
# TFORM68 = 'E       '           / format for column 68
# TTYPE69 = 'lg_M_Lh_bestfit_0'  / label for column 69
# TFORM69 = 'E       '           / format for column 69
# TTYPE70 = 'lg_M_Lk_bestfit_0'  / label for column 70
# TFORM70 = 'E       '           / format for column 70
# TTYPE71 = 'CTIO_U_bestfit_0'   / label for column 71
# TFORM71 = 'E       '           / format for column 71
# TTYPE72 = 'VIMOS_U_bestfit_0'  / label for column 72
# TFORM72 = 'E       '           / format for column 72
# TTYPE73 = 'ACS_F435W_bestfit_0' / label for column 73
# TFORM73 = 'E       '           / format for column 73
# TTYPE74 = 'ACS_F606W_bestfit_0' / label for column 74
# TFORM74 = 'E       '           / format for column 74
# TTYPE75 = 'ACS_F775W_bestfit_0' / label for column 75
# TFORM75 = 'E       '           / format for column 75
# TTYPE76 = 'ACS_F814W_bestfit_0' / label for column 76
# TFORM76 = 'E       '           / format for column 76
# TTYPE77 = 'ACS_F850LP_bestfit_0' / label for column 77
# TFORM77 = 'E       '           / format for column 77
# TTYPE78 = 'WFC3_F098M_bestfit_0' / label for column 78
# TFORM78 = 'E       '           / format for column 78
# TTYPE79 = 'WFC3_F105W_bestfit_0' / label for column 79
# TFORM79 = 'E       '           / format for column 79
# TTYPE80 = 'WFC3_F125W_bestfit_0' / label for column 80
# TFORM80 = 'E       '           / format for column 80
# TTYPE81 = 'WFC3_F160W_bestfit_0' / label for column 81
# TFORM81 = 'E       '           / format for column 81
# TTYPE82 = 'ISAAC_KS_bestfit_0' / label for column 82
# TFORM82 = 'E       '           / format for column 82
# TTYPE83 = 'HAWKI_KS_bestfit_0' / label for column 83
# TFORM83 = 'E       '           / format for column 83
# TTYPE84 = 'IRAC_CH1_bestfit_0' / label for column 84
# TFORM84 = 'E       '           / format for column 84
# TTYPE85 = 'IRAC_CH2_bestfit_0' / label for column 85
# TFORM85 = 'E       '           / format for column 85
# TTYPE86 = 'IRAC_CH3_bestfit_0' / label for column 86
# TFORM86 = 'E       '           / format for column 86
# TTYPE87 = 'IRAC_CH4_bestfit_0' / label for column 87
# TFORM87 = 'E       '           / format for column 87
# TTYPE88 = 'f24_0_1a'           / label for column 88
# TFORM88 = 'E       '           / format for column 88
# TTYPE89 = 'f70_bestfit_0'      / label for column 89
# TFORM89 = 'E       '           / format for column 89
# TTYPE90 = 'f100_bestfit_0'     / label for column 90
# TFORM90 = 'E       '           / format for column 90
# TTYPE91 = 'f160_bestfit_0'     / label for column 91
# TFORM91 = 'E       '           / format for column 91
# TTYPE92 = 'f250_bestfit_0'     / label for column 92
# TFORM92 = 'E       '           / format for column 92
# TTYPE93 = 'mu2_5_0 '           / label for column 93
# TFORM93 = 'E       '           / format for column 93
# TTYPE94 = 'mu16_0  '           / label for column 94
# TFORM94 = 'E       '           / format for column 94
# TTYPE95 = 'mu50_0  '           / label for column 95
# TFORM95 = 'E       '           / format for column 95
# TTYPE96 = 'mu84_0  '           / label for column 96
# TFORM96 = 'E       '           / format for column 96
# TTYPE97 = 'mu97_5_0'           / label for column 97
# TFORM97 = 'E       '           / format for column 97
# TTYPE98 = 'tau_v2_5_0'         / label for column 98
# TFORM98 = 'E       '           / format for column 98
# TTYPE99 = 'tau_v16_0'          / label for column 99
# TFORM99 = 'E       '           / format for column 99
# TTYPE100= 'tau_v50_0'          / label for column 100
# TFORM100= 'E       '           / format for column 100
# TTYPE101= 'tau_v84_0'          / label for column 101
# TFORM101= 'E       '           / format for column 101
# TTYPE102= 'tauv_87_5_0'        / label for column 102
# TFORM102= 'E       '           / format for column 102
# TTYPE103= 'sSFR2_5_0'          / label for column 103
# TFORM103= 'E       '           / format for column 103
# TTYPE104= 'sSFR16_0'           / label for column 104
# TFORM104= 'E       '           / format for column 104
# TTYPE105= 'sSFR50_0'           / label for column 105
# TFORM105= 'E       '           / format for column 105
# TTYPE106= 'sSFR84_0'           / label for column 106
# TFORM106= 'E       '           / format for column 106
# TTYPE107= 'sSFR97_5_0'         / label for column 107
# TFORM107= 'E       '           / format for column 107
# TTYPE108= 'Mstar2_5_0'         / label for column 108
# TFORM108= 'E       '           / format for column 108
# TTYPE109= 'Mstar16_0'          / label for column 109
# TFORM109= 'E       '           / format for column 109
# TTYPE110= 'Mstar50_0'          / label for column 110
# TFORM110= 'E       '           / format for column 110
# TTYPE111= 'Mstar84_0'          / label for column 111
# TFORM111= 'E       '           / format for column 111
# TTYPE112= 'Mstar_97_5_0'       / label for column 112
# TFORM112= 'E       '           / format for column 112
# TTYPE113= 'Ldust2_5_0'         / label for column 113
# TFORM113= 'E       '           / format for column 113
# TTYPE114= 'Ldust16_0'          / label for column 114
# TFORM114= 'E       '           / format for column 114
# TTYPE115= 'Ldust50_0'          / label for column 115
# TFORM115= 'E       '           / format for column 115
# TTYPE116= 'Ldust84_0'          / label for column 116
# TFORM116= 'E       '           / format for column 116
# TTYPE117= 'Ldust97_5_0'        / label for column 117
# TFORM117= 'E       '           / format for column 117
# TTYPE118= 'Mdust2_5_0'         / label for column 118
# TFORM118= 'E       '           / format for column 118
# TTYPE119= 'Mdust16_0'          / label for column 119
# TFORM119= 'E       '           / format for column 119
# TTYPE120= 'Mdust50_0'          / label for column 120
# TFORM120= 'E       '           / format for column 120
# TTYPE121= 'Mdust84_0'          / label for column 121
# TFORM121= 'E       '           / format for column 121
# TTYPE122= 'Mdust97_5_0'        / label for column 122
# TFORM122= 'E       '           / format for column 122
# TTYPE123= 'SFR2_5_0'           / label for column 123
# TFORM123= 'E       '           / format for column 123
# TTYPE124= 'SFR16_0 '           / label for column 124
# TFORM124= 'E       '           / format for column 124
# TTYPE125= 'SFR50_0 '           / label for column 125
# TFORM125= 'E       '           / format for column 125
# TTYPE126= 'SFR84_0 '           / label for column 126
# TFORM126= 'E       '           / format for column 126
# TTYPE127= 'SFR97_5_0'          / label for column 127
# TFORM127= 'E       '           / format for column 127
# TTYPE128= 'age_M2_5_0'         / label for column 128
# TFORM128= 'E       '           / format for column 128
# TTYPE129= 'age_M16_0'          / label for column 129
# TFORM129= 'E       '           / format for column 129
# TTYPE130= 'age_M50_0'          / label for column 130
# TFORM130= 'E       '           / format for column 130
# TTYPE131= 'age_M84_0'          / label for column 131
# TFORM131= 'E       '           / format for column 131
# TTYPE132= 'age_M97_5_0'        / label for column 132
# TFORM132= 'E       '           / format for column 132
# TTYPE133= 'Mstar_L_H2_5_0'     / label for column 133
# TFORM133= 'E       '           / format for column 133
# TTYPE134= 'Mstar_L_H16_0'      / label for column 134
# TFORM134= 'E       '           / format for column 134
# TTYPE135= 'Mstar_L_H50_0'      / label for column 135
# TFORM135= 'E       '           / format for column 135
# TTYPE136= 'Mstar_L_H84_0'      / label for column 136
# TFORM136= 'E       '           / format for column 136
# TTYPE137= 'Mstar_L_H97_5_0'    / label for column 137
# TFORM137= 'E       '           / format for column 137
# TTYPE138= 'Mstar_L_K2_5_0'     / label for column 138
# TFORM138= 'E       '           / format for column 138
# TTYPE139= 'Mstar_L_K16_0'      / label for column 139
# TFORM139= 'E       '           / format for column 139
# TTYPE140= 'Mstar_L_K50_0'      / label for column 140
# TFORM140= 'E       '           / format for column 140
# TTYPE141= 'Mstar_L_K84_0'      / label for column 141
# TFORM141= 'E       '           / format for column 141
# TTYPE142= 'Mstar_L_K97_5_0'    / label for column 142
# TFORM142= 'E       '           / format for column 142
# TTYPE143= 'A_V2_5_0'           / label for column 143
# TFORM143= 'E       '           / format for column 143
# TTYPE144= 'A_V16_0 '           / label for column 144
# TFORM144= 'E       '           / format for column 144
# TTYPE145= 'A_V50_0 '           / label for column 145
# TFORM145= 'E       '           / format for column 145
# TTYPE146= 'A_V84_0 '           / label for column 146
# TFORM146= 'E       '           / format for column 146
# TTYPE147= 'A_V97_5_0'          / label for column 147
# TFORM147= 'E       '           / format for column 147
# TTYPE148= 'Tdust2_5_0'         / label for column 148
# TFORM148= 'E       '           / format for column 148
# TTYPE149= 'Tdust16_0'          / label for column 149
# TFORM149= 'E       '           / format for column 149
# TTYPE150= 'Tdust50_0'          / label for column 150
# TFORM150= 'E       '           / format for column 150
# TTYPE151= 'Tdust84_0'          / label for column 151
# TFORM151= 'E       '           / format for column 151
# TTYPE152= 'Tdust97_5_0'        / label for column 152
# TFORM152= 'E       '           / format for column 152
# TTYPE153= 'sSFR2_5_0_10M'      / label for column 153
# TFORM153= 'E       '           / format for column 153
# TTYPE154= 'sSFR16_0_10M'       / label for column 154
# TFORM154= 'E       '           / format for column 154
# TTYPE155= 'sSFR50_0_10M'       / label for column 155
# TFORM155= 'E       '           / format for column 155
# TTYPE156= 'sSFR84_0_10M'       / label for column 156
# TFORM156= 'E       '           / format for column 156
# TTYPE157= 'sSFR97_5_0_10M'     / label for column 157
# TFORM157= 'E       '           / format for column 157
# TTYPE158= 'ID_agn  '           / label for column 158
# TFORM158= '9A      '           / format for column 158
# TTYPE159= 'CTIO_U_agn'         / label for column 159
# TFORM159= 'E       '           / format for column 159
# TTYPE160= 'VIMOS_U_agn'        / label for column 160
# TFORM160= 'E       '           / format for column 160
# TTYPE161= 'ACS_F435W_agn'      / label for column 161
# TFORM161= 'E       '           / format for column 161
# TTYPE162= 'ACS_F606W_agn'      / label for column 162
# TFORM162= 'E       '           / format for column 162
# TTYPE163= 'ACS_F775W_agn'      / label for column 163
# TFORM163= 'E       '           / format for column 163
# TTYPE164= 'ACS_F814W_agn'      / label for column 164
# TFORM164= 'E       '           / format for column 164
# TTYPE165= 'ACS_F850LP_agn'     / label for column 165
# TFORM165= 'E       '           / format for column 165
# TTYPE166= 'WFC3_F098M_agn'     / label for column 166
# TFORM166= 'E       '           / format for column 166
# TTYPE167= 'WFC3_F105W_agn'     / label for column 167
# TFORM167= 'E       '           / format for column 167
# TTYPE168= 'WFC3_F125W_agn'     / label for column 168
# TFORM168= 'E       '           / format for column 168
# TTYPE169= 'WFC3_F160W_agn'     / label for column 169
# TFORM169= 'E       '           / format for column 169
# TTYPE170= 'ISAAC_KS_agn'       / label for column 170
# TFORM170= 'E       '           / format for column 170
# TTYPE171= 'HAWKI_KS_agn'       / label for column 171
# TFORM171= 'E       '           / format for column 171
# TTYPE172= 'IRAC_CH1_agn'       / label for column 172
# TFORM172= 'E       '           / format for column 172
# TTYPE173= 'IRAC_CH2_agn'       / label for column 173
# TFORM173= 'E       '           / format for column 173
# TTYPE174= 'IRAC_CH3_agn'       / label for column 174
# TFORM174= 'E       '           / format for column 174
# TTYPE175= 'IRAC_CH4_agn'       / label for column 175
# TFORM175= 'E       '           / format for column 175
# TTYPE176= 'f24_agn '           / label for column 176
# TFORM176= 'E       '           / format for column 176
# TTYPE177= 'f70_agn '           / label for column 177
# TFORM177= 'E       '           / format for column 177
# TTYPE178= 'f100_agn'           / label for column 178
# TFORM178= 'E       '           / format for column 178
# TTYPE179= 'f160_agn'           / label for column 179
# TFORM179= 'E       '           / format for column 179
# TTYPE180= 'f250_agn'           / label for column 180
# TFORM180= 'E       '           / format for column 180
# TTYPE181= 'eCTIO_U_agn'        / label for column 181
# TFORM181= 'E       '           / format for column 181
# TTYPE182= 'eVIMOS_U_agn'       / label for column 182
# TFORM182= 'E       '           / format for column 182
# TTYPE183= 'eACS_F435W_agn'     / label for column 183
# TFORM183= 'E       '           / format for column 183
# TTYPE184= 'eACS_F606W_agn'     / label for column 184
# TFORM184= 'E       '           / format for column 184
# TTYPE185= 'eACS_F775W_agn'     / label for column 185
# TFORM185= 'E       '           / format for column 185
# TTYPE186= 'eACS_F814W_agn'     / label for column 186
# TFORM186= 'E       '           / format for column 186
# TTYPE187= 'eACS_F850LP_agn'    / label for column 187
# TFORM187= 'E       '           / format for column 187
# TTYPE188= 'eWFC3_F098M_agn'    / label for column 188
# TFORM188= 'E       '           / format for column 188
# TTYPE189= 'eWFC3_F105W_agn'    / label for column 189
# TFORM189= 'E       '           / format for column 189
# TTYPE190= 'eWFC3_F125W_agn'    / label for column 190
# TFORM190= 'E       '           / format for column 190
# TTYPE191= 'eWFC3_F160W_agn'    / label for column 191
# TFORM191= 'E       '           / format for column 191
# TTYPE192= 'eISAAC_KS_agn'      / label for column 192
# TFORM192= 'E       '           / format for column 192
# TTYPE193= 'eHAWKI_KS_agn'      / label for column 193
# TFORM193= 'E       '           / format for column 193
# TTYPE194= 'eIRAC_CH1_agn'      / label for column 194
# TFORM194= 'E       '           / format for column 194
# TTYPE195= 'eIRAC_CH2_agn'      / label for column 195
# TFORM195= 'E       '           / format for column 195
# TTYPE196= 'eIRAC_CH3_agn'      / label for column 196
# TFORM196= 'E       '           / format for column 196
# TTYPE197= 'eIRAC_CH4_agn'      / label for column 197
# TFORM197= 'E       '           / format for column 197
# TTYPE198= 'ef24_agn'           / label for column 198
# TFORM198= 'E       '           / format for column 198
# TTYPE199= 'ef70_agn'           / label for column 199
# TFORM199= 'E       '           / format for column 199
# TTYPE200= 'ef100_agn'          / label for column 200
# TFORM200= 'E       '           / format for column 200
# TTYPE201= 'ef160_agn'          / label for column 201
# TFORM201= 'E       '           / format for column 201
# TTYPE202= 'ef250_agn'          / label for column 202
# TFORM202= 'E       '           / format for column 202
# TTYPE203= 'i_sfh_agn'          / label for column 203
# TFORM203= 'I       '           / format for column 203
# TTYPE204= 'i_ir_agn'           / label for column 204
# TFORM204= 'I       '           / format for column 204
# TTYPE205= 'i_agn_agn'          / label for column 205
# TFORM205= 'I       '           / format for column 205
# TTYPE206= 'chi2_agn'           / label for column 206
# TFORM206= 'E       '           / format for column 206
# TTYPE207= 'redshift_agn'       / label for column 207
# TFORM207= 'D       '           / format for column 207
# TTYPE208= 'fmu_SFH_bestfit_agn' / label for column 208
# TFORM208= 'E       '           / format for column 208
# TTYPE209= 'fmu_IR_bestfit_agn' / label for column 209
# TFORM209= 'E       '           / format for column 209
# TTYPE210= 'mu_bestfit_agn'     / label for column 210
# TFORM210= 'E       '           / format for column 210
# TTYPE211= 'tauv_bestfit_agn'   / label for column 211
# TFORM211= 'E       '           / format for column 211
# TTYPE212= 'sSFR_bestfit_agn'   / label for column 212
# TFORM212= 'E       '           / format for column 212
# TTYPE213= 'Mstar_bestfit_agn'  / label for column 213
# TFORM213= 'E       '           / format for column 213
# TTYPE214= 'Ldust_bestfit_agn'  / label for column 214
# TFORM214= 'E       '           / format for column 214
# TTYPE215= 'Ldust_SF_bestfit_agn' / label for column 215
# TFORM215= 'E       '           / format for column 215
# TTYPE216= 'Ldust_AGN_bestfit_agn' / label for column 216
# TFORM216= 'E       '           / format for column 216
# TTYPE217= 'T_W_BC_bestfit_agn' / label for column 217
# TFORM217= 'E       '           / format for column 217
# TTYPE218= 'T_C_ISM_bestfit_agn' / label for column 218
# TFORM218= 'E       '           / format for column 218
# TTYPE219= 'xi_C_tot_bestfit_agn' / label for column 219
# TFORM219= 'E       '           / format for column 219
# TTYPE220= 'xi_PAH_tot_bestfit_agn' / label for column 220
# TFORM220= 'E       '           / format for column 220
# TTYPE221= 'xi_MIR_tot_bestfit_agn' / label for column 221
# TFORM221= 'E       '           / format for column 221
# TTYPE222= 'xi_W_tot_bestfit_agn' / label for column 222
# TFORM222= 'E       '           / format for column 222
# TTYPE223= 'tvism_bestfit_agn'  / label for column 223
# TFORM223= 'E       '           / format for column 223
# TTYPE224= 'Mdust_bestfit_agn'  / label for column 224
# TFORM224= 'E       '           / format for column 224
# TTYPE225= 'SFR_bestfit_agn'    / label for column 225
# TFORM225= 'E       '           / format for column 225
# TTYPE226= 'A_V_bestfit_agn'    / label for column 226
# TFORM226= 'E       '           / format for column 226
# TTYPE227= 'age_M_bestfit_agn'  / label for column 227
# TFORM227= 'E       '           / format for column 227
# TTYPE228= 'Tdust_bestfit_agn'  / label for column 228
# TFORM228= 'E       '           / format for column 228
# TTYPE229= 'lg_M_Lh_bestfit_agn' / label for column 229
# TFORM229= 'E       '           / format for column 229
# TTYPE230= 'lg_M_Lk_bestfit_agn' / label for column 230
# TFORM230= 'E       '           / format for column 230
# TTYPE231= 'xi_AGN_bestfit'     / label for column 231
# TFORM231= 'E       '           / format for column 231
# TTYPE232= 'CTIO_U_bestfit_agn' / label for column 232
# TFORM232= 'E       '           / format for column 232
# TTYPE233= 'VIMOS_U_bestfit_agn' / label for column 233
# TFORM233= 'E       '           / format for column 233
# TTYPE234= 'ACS_F435W_bestfit_agn' / label for column 234
# TFORM234= 'E       '           / format for column 234
# TTYPE235= 'ACS_F606W_bestfit_agn' / label for column 235
# TFORM235= 'E       '           / format for column 235
# TTYPE236= 'ACS_F775W_bestfit_agn' / label for column 236
# TFORM236= 'E       '           / format for column 236
# TTYPE237= 'ACS_F814W_bestfit_agn' / label for column 237
# TFORM237= 'E       '           / format for column 237
# TTYPE238= 'ACS_F850LP_bestfit_agn' / label for column 238
# TFORM238= 'E       '           / format for column 238
# TTYPE239= 'WFC3_F098M_bestfit_agn' / label for column 239
# TFORM239= 'E       '           / format for column 239
# TTYPE240= 'WFC3_F105W_bestfit_agn' / label for column 240
# TFORM240= 'E       '           / format for column 240
# TTYPE241= 'WFC3_F125W_bestfit_agn' / label for column 241
# TFORM241= 'E       '           / format for column 241
# TTYPE242= 'WFC3_F160W_bestfit_agn' / label for column 242
# TFORM242= 'E       '           / format for column 242
# TTYPE243= 'ISAAC_KS_bestfit_agn' / label for column 243
# TFORM243= 'E       '           / format for column 243
# TTYPE244= 'HAWKI_KS_bestfit_agn' / label for column 244
# TFORM244= 'E       '           / format for column 244
# TTYPE245= 'IRAC_CH1_bestfit_agn' / label for column 245
# TFORM245= 'E       '           / format for column 245
# TTYPE246= 'IRAC_CH2_bestfit_agn' / label for column 246
# TFORM246= 'E       '           / format for column 246
# TTYPE247= 'IRAC_CH3_bestfit_agn' / label for column 247
# TFORM247= 'E       '           / format for column 247
# TTYPE248= 'IRAC_CH4_bestfit_agn' / label for column 248
# TFORM248= 'E       '           / format for column 248
# TTYPE249= 'f24_bestfit_agn'    / label for column 249
# TFORM249= 'E       '           / format for column 249
# TTYPE250= 'f70_bestfit_agn'    / label for column 250
# TFORM250= 'E       '           / format for column 250
# TTYPE251= 'f100_bestfit_agn'   / label for column 251
# TFORM251= 'E       '           / format for column 251
# TTYPE252= 'f160_bestfit_agn'   / label for column 252
# TFORM252= 'E       '           / format for column 252
# TTYPE253= 'f250_bestfit_agn'   / label for column 253
# TFORM253= 'E       '           / format for column 253
# TTYPE254= 'mu2_5_agn'          / label for column 254
# TFORM254= 'E       '           / format for column 254
# TTYPE255= 'mu16_agn'           / label for column 255
# TFORM255= 'E       '           / format for column 255
# TTYPE256= 'mu50_agn'           / label for column 256
# TFORM256= 'E       '           / format for column 256
# TTYPE257= 'mu84_agn'           / label for column 257
# TFORM257= 'E       '           / format for column 257
# TTYPE258= 'mu97_5_agn'         / label for column 258
# TFORM258= 'E       '           / format for column 258
# TTYPE259= 'tau_v2_5_agn'       / label for column 259
# TFORM259= 'E       '           / format for column 259
# TTYPE260= 'tau_v16_agn'        / label for column 260
# TFORM260= 'E       '           / format for column 260
# TTYPE261= 'tau_v50_agn'        / label for column 261
# TFORM261= 'E       '           / format for column 261
# TTYPE262= 'tau_v84_agn'        / label for column 262
# TFORM262= 'E       '           / format for column 262
# TTYPE263= 'tauv_87_5_agn'      / label for column 263
# TFORM263= 'E       '           / format for column 263
# TTYPE264= 'sSFR2_5_agn'        / label for column 264
# TFORM264= 'E       '           / format for column 264
# TTYPE265= 'sSFR16_agn'         / label for column 265
# TFORM265= 'E       '           / format for column 265
# TTYPE266= 'sSFR50_agn'         / label for column 266
# TFORM266= 'E       '           / format for column 266
# TTYPE267= 'sSFR84_agn'         / label for column 267
# TFORM267= 'E       '           / format for column 267
# TTYPE268= 'sSFR97_5_agn'       / label for column 268
# TFORM268= 'E       '           / format for column 268
# TTYPE269= 'Mstar2_5_agn'       / label for column 269
# TFORM269= 'E       '           / format for column 269
# TTYPE270= 'Mstar16_agn'        / label for column 270
# TFORM270= 'E       '           / format for column 270
# TTYPE271= 'Mstar50_agn'        / label for column 271
# TFORM271= 'E       '           / format for column 271
# TTYPE272= 'Mstar84_agn'        / label for column 272
# TFORM272= 'E       '           / format for column 272
# TTYPE273= 'Mstar_97_5_agn'     / label for column 273
# TFORM273= 'E       '           / format for column 273
# TTYPE274= 'Ldust2_5_agn'       / label for column 274
# TFORM274= 'E       '           / format for column 274
# TTYPE275= 'Ldust16_agn'        / label for column 275
# TFORM275= 'E       '           / format for column 275
# TTYPE276= 'Ldust50_agn'        / label for column 276
# TFORM276= 'E       '           / format for column 276
# TTYPE277= 'Ldust84_agn'        / label for column 277
# TFORM277= 'E       '           / format for column 277
# TTYPE278= 'Ldust97_5_agn'      / label for column 278
# TFORM278= 'E       '           / format for column 278
# TTYPE279= 'Mdust2_5_agn'       / label for column 279
# TFORM279= 'E       '           / format for column 279
# TTYPE280= 'Mdust16_agn'        / label for column 280
# TFORM280= 'E       '           / format for column 280
# TTYPE281= 'Mdust50_agn'        / label for column 281
# TFORM281= 'E       '           / format for column 281
# TTYPE282= 'Mdust84_agn'        / label for column 282
# TFORM282= 'E       '           / format for column 282
# TTYPE283= 'Mdust97_5_agn'      / label for column 283
# TFORM283= 'E       '           / format for column 283
# TTYPE284= 'SFR2_5_agn'         / label for column 284
# TFORM284= 'E       '           / format for column 284
# TTYPE285= 'SFR16_agn'          / label for column 285
# TFORM285= 'E       '           / format for column 285
# TTYPE286= 'SFR50_agn'          / label for column 286
# TFORM286= 'E       '           / format for column 286
# TTYPE287= 'SFR84_agn'          / label for column 287
# TFORM287= 'E       '           / format for column 287
# TTYPE288= 'SFR97_5_agn'        / label for column 288
# TFORM288= 'E       '           / format for column 288
# TTYPE289= 'age_M2_5_agn'       / label for column 289
# TFORM289= 'E       '           / format for column 289
# TTYPE290= 'age_M16_agn'        / label for column 290
# TFORM290= 'E       '           / format for column 290
# TTYPE291= 'age_M50_agn'        / label for column 291
# TFORM291= 'E       '           / format for column 291
# TTYPE292= 'age_M84_agn'        / label for column 292
# TFORM292= 'E       '           / format for column 292
# TTYPE293= 'age_M97_5_agn'      / label for column 293
# TFORM293= 'E       '           / format for column 293
# TTYPE294= 'Mstar_L_H2_5_agn'   / label for column 294
# TFORM294= 'E       '           / format for column 294
# TTYPE295= 'Mstar_L_H16_agn'    / label for column 295
# TFORM295= 'E       '           / format for column 295
# TTYPE296= 'Mstar_L_H50_agn'    / label for column 296
# TFORM296= 'E       '           / format for column 296
# TTYPE297= 'Mstar_L_H84_agn'    / label for column 297
# TFORM297= 'E       '           / format for column 297
# TTYPE298= 'Mstar_L_H97_5_agn'  / label for column 298
# TFORM298= 'E       '           / format for column 298
# TTYPE299= 'Mstar_L_K2_5_agn'   / label for column 299
# TFORM299= 'E       '           / format for column 299
# TTYPE300= 'Mstar_L_K16_agn'    / label for column 300
# TFORM300= 'E       '           / format for column 300
# TTYPE301= 'Mstar_L_K50_agn'    / label for column 301
# TFORM301= 'E       '           / format for column 301
# TTYPE302= 'Mstar_L_K84_agn'    / label for column 302
# TFORM302= 'E       '           / format for column 302
# TTYPE303= 'Mstar_L_K97_5_agn'  / label for column 303
# TFORM303= 'E       '           / format for column 303
# TTYPE304= 'A_V2_5_agn'         / label for column 304
# TFORM304= 'E       '           / format for column 304
# TTYPE305= 'A_V16_agn'          / label for column 305
# TFORM305= 'E       '           / format for column 305
# TTYPE306= 'A_V50_agn'          / label for column 306
# TFORM306= 'E       '           / format for column 306
# TTYPE307= 'A_V84_agn'          / label for column 307
# TFORM307= 'E       '           / format for column 307
# TTYPE308= 'A_V97_5_agn'        / label for column 308
# TFORM308= 'E       '           / format for column 308
# TTYPE309= 'Tdust2_5_agn'       / label for column 309
# TFORM309= 'E       '           / format for column 309
# TTYPE310= 'Tdust16_agn'        / label for column 310
# TFORM310= 'E       '           / format for column 310
# TTYPE311= 'Tdust50_agn'        / label for column 311
# TFORM311= 'E       '           / format for column 311
# TTYPE312= 'Tdust84_agn'        / label for column 312
# TFORM312= 'E       '           / format for column 312
# TTYPE313= 'Tdust97_5_agn'      / label for column 313
# TFORM313= 'E       '           / format for column 313
# TTYPE314= 'agnf2_5_agn'        / label for column 314
# TFORM314= 'E       '           / format for column 314
# TTYPE315= 'agnf16_agn'         / label for column 315
# TFORM315= 'E       '           / format for column 315
# TTYPE316= 'agnf50_agn'         / label for column 316
# TFORM316= 'E       '           / format for column 316
# TTYPE317= 'agnf84_agn'         / label for column 317
# TFORM317= 'E       '           / format for column 317
# TTYPE318= 'agnf97_5_agn'       / label for column 318
# TFORM318= 'E       '           / format for column 318
# TTYPE319= 'Ldustsf2_5_agn'     / label for column 319
# TFORM319= 'E       '           / format for column 319
# TTYPE320= 'Ldustsf16_agn'      / label for column 320
# TFORM320= 'E       '           / format for column 320
# TTYPE321= 'Ldustsf50_agn'      / label for column 321
# TFORM321= 'E       '           / format for column 321
# TTYPE322= 'Ldustsf84_agn'      / label for column 322
# TFORM322= 'E       '           / format for column 322
# TTYPE323= 'Ldustsf97_5_agn'    / label for column 323
# TFORM323= 'E       '           / format for column 323
# TTYPE324= 'Ldustagn2_5_agn'    / label for column 324
# TFORM324= 'E       '           / format for column 324
# TTYPE325= 'Ldustagn16_agn'     / label for column 325
# TFORM325= 'E       '           / format for column 325
# TTYPE326= 'Ldustagn50_agn'     / label for column 326
# TFORM326= 'E       '           / format for column 326
# TTYPE327= 'Ldustagn84_agn'     / label for column 327
# TFORM327= 'E       '           / format for column 327
# TTYPE328= 'Ldustagn97_5_agn'   / label for column 328
# TFORM328= 'E       '           / format for column 328
# TTYPE329= 'SFR2_5_agn_10M'     / label for column 329
# TFORM329= 'E       '           / format for column 329
# TTYPE330= 'SFR16_agn_10M'      / label for column 330
# TFORM330= 'E       '           / format for column 330
# TTYPE331= 'SFR50_agn_10M'      / label for column 331
# TFORM331= 'E       '           / format for column 331
# TTYPE332= 'SFR84_agn_10M'      / label for column 332
# TFORM332= 'E       '           / format for column 332
# TTYPE333= 'SFR97_5_agn_10M'    / label for column 333
# TFORM333= 'E       '           / format for column 333
# DATE-HDU= '2018-09-13T14:59:29' / Date of HDU creation (UTC)
# STILVERS= '3.1-2   '           / Version of STIL software
# STILCLAS= 'uk.ac.starlink.votable.FitsPlusTableWriter' / Author class in STIL so

# %%
temp = magphys_IR_full[1].data
len(temp)
# Out:
# 365

# %%
magphys_ir_ids = np.zeros((len(cat_z1_ids),))

magphys_ir_mass = np.zeros((len(cat_z1_ids),))
magphys_ir_sfr = np.zeros((len(cat_z1_ids),))
magphys_ir_av = np.zeros((len(cat_z1_ids),))

magphys_ir_mass_AGN = np.zeros((len(cat_z1_ids),))
magphys_ir_sfr_AGN = np.zeros((len(cat_z1_ids),))
magphys_ir_av_AGN = np.zeros((len(cat_z1_ids),))


for i in range(len(magphys_IR_full[1].data)):
    
    temp = magphys_IR_full[1].data[i][0]
    id_index = np.argmin(np.abs(cat_z1_ids - float(temp[0:-4])))
    
    magphys_ir_ids[id_index] = float(temp[0:-4])
    
    magphys_ir_mass[id_index] = magphys_IR_full[1].data[i][109]
    magphys_ir_sfr[id_index] = magphys_IR_full[1].data[i][124]
    magphys_ir_av[id_index] = magphys_IR_full[1].data[i][144]
    
    magphys_ir_mass_AGN[id_index] = magphys_IR_full[1].data[i][270]
    magphys_ir_sfr_AGN[id_index] = magphys_IR_full[1].data[i][285]
    magphys_ir_av_AGN[id_index] = magphys_IR_full[1].data[i][305]

# %%
plt.plot(cat_z1_ids, magphys_ir_ids,'.')
plt.show()

# %%
magphys_IR_full.close()

# %% [markdown]
# # Bagpipes
#
# ID
# dust:Av_16 dust:Av_median dust:Av_84
# dblplaw:tau_16 dblplaw:tau_median dblplaw:tau_84
# dblplaw:metallicity_16 dblplaw:metallicity_median dblplaw:metallicity_84
# dblplaw:beta_16 dblplaw:beta_median dblplaw:beta_84
# dblplaw:massformed_16 dblplaw:massformed_median dblplaw:massformed_84
# dblplaw:alpha_16 dblplaw:alpha_median dblplaw:alpha_84
# UVcolour_16 UVcolour_median UVcolour_84
# VJcolour_16 VJcolour_median VJcolour_84
# tmw_16 tmw_median tmw_84
# sfr_16 sfr_median sfr_84
# mstar_liv_16 mstar_liv_median mstar_liv_84
# z_input log_evidence log_evidence_err min_chisq_reduced

# %%
bagpipes_IR_cat = np.genfromtxt('code_outputs_IR/bagpipes_ucr_z1_ir_results.cat')

bagpipes_IR_ids = bagpipes_IR_cat[0:,0]

bagpipes_IR_mass = np.log10(bagpipes_IR_cat[0:,32])
bagpipes_IR_sfr = np.log10(bagpipes_IR_cat[0:,29])
bagpipes_IR_av = bagpipes_IR_cat[0:,2]

# %%
plt.scatter(bagpipes_IR_mass, bagpipes_IR_sfr, c=bagpipes_IR_av,cmap='magma')
plt.axis([8,12,-3,3])
plt.show()

# %%
bagpipes_cat_z1 = np.genfromtxt('code_outputs/bagpipes_z1_cat_pipes_output.txt')
print(bagpipes_cat_z1.shape)

bagpipes_id = bagpipes_cat_z1[0:,0]

bagpipes_Av_lo_z1= bagpipes_cat_z1[0:,1]
bagpipes_Av_z1 = bagpipes_cat_z1[0:,2]
bagpipes_Av_hi_z1 = bagpipes_cat_z1[0:,3]

bagpipes_mass_lo_z1 = np.log10(bagpipes_cat_z1[0:,34])
bagpipes_mass_z1 = np.log10(bagpipes_cat_z1[0:,35])
bagpipes_mass_hi_z1 = np.log10(bagpipes_cat_z1[0:,36])

bagpipes_sfr_lo_z1 = np.log10(bagpipes_cat_z1[0:,31])
bagpipes_sfr_z1 = np.log10(bagpipes_cat_z1[0:,32])
bagpipes_sfr_hi_z1 = np.log10(bagpipes_cat_z1[0:,33])
# Out:
# (371, 41)

# %% [markdown]
# # CIGALE

# %%
c1 = fits.open('code_outputs_IR/cigale_without_IR_without_AGNs_results.fits')
c1.info()
c1[1].header
# Out:
# Filename: code_outputs_IR/cigale_without_IR_without_AGNs_results.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      16   (936,)   uint8
#   1  /data06/HELP/DATA/Denis_CANDELS/withoutIR_withoutAGNs/stellar/res...  BinTableHDU     32   371R x 7C   [K, D, D, D, D, D, D]
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                   56 / width of table in bytes
# NAXIS2  =                  371 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                    7 / number of columns
# EXTNAME = '/data06/HELP/DATA/Denis_CANDELS/withoutIR_withoutAGNs/stellar/res...'
# TTYPE1  = 'id      '           / label for column 1
# TFORM1  = 'K       '           / format for column 1
# TTYPE2  = 'logMstar'           / label for column 2
# TFORM2  = 'D       '           / format for column 2
# TCOMM2  = '(log10($2))'
# TTYPE3  = 'logMstar_err'       / label for column 3
# TFORM3  = 'D       '           / format for column 3
# TCOMM3  = '($3/$2) '
# TTYPE4  = 'logSFR  '           / label for column 4
# TFORM4  = 'D       '           / format for column 4
# TCOMM4  = '(log10($4))'
# TTYPE5  = 'logSFR_err'         / label for column 5
# TFORM5  = 'D       '           / format for column 5
# TCOMM5  = '($5/$4) '
# TTYPE6  = 'att_V   '           / label for column 6
# TFORM6  = 'D       '           / format for column 6
# TCOMM6  = '($14)   '
# TTYPE7  = 'att_V_err'          / label for column 7
# TFORM7  = 'D       '           / format for column 7
# TCOMM7  = '($15)   '
# DATE-HDU= '2018-09-17T09:17:39' / Date of HDU creation (UTC)
# STILVERS= '3.1     '           / Version of STIL software
# STILCLAS= 'uk.ac.starlink.votable.FitsPlusTableWriter' / Author class in STIL so

# %%
cigale_ids = np.zeros((len(cat_z1_ids),))

cigale_mass = np.zeros((len(cat_z1_ids),))
cigale_sfr = np.zeros((len(cat_z1_ids),))
cigale_Av = np.zeros((len(cat_z1_ids),))

for i in range(len(cat_z1_ids)):
    temp = c1[1].data[i][0]
    
    cigale_ids[i] = temp
    cigale_mass[i] = c1[1].data[i][1]
    cigale_sfr[i] = c1[1].data[i][3]
    cigale_Av[i] = c1[1].data[i][5]
    
c1.close()

# %%
c2 = fits.open('code_outputs_IR/cigale_wit_IR_without_AGNs_results.fits')
c2.info()


cigale_ir_ids = np.zeros((len(cat_z1_ids),))

cigale_ir_mass = np.zeros((len(cat_z1_ids),))
cigale_ir_sfr = np.zeros((len(cat_z1_ids),))
cigale_ir_Av = np.zeros((len(cat_z1_ids),))

for i in range(len(cat_z1_ids)):
    temp = c2[1].data[i][0]
    
    cigale_ir_ids[i] = temp
    cigale_ir_mass[i] = c2[1].data[i][1]
    cigale_ir_sfr[i] = c2[1].data[i][3]
    cigale_ir_Av[i] = c2[1].data[i][5]
    
    
c2[1].header
c2.close()
# Out:
# Filename: code_outputs_IR/cigale_wit_IR_without_AGNs_results.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      16   (933,)   uint8
#   1  /data06/HELP/DATA/Denis_CANDELS/withIR_withoutAGNs/UVoptIR/result...  BinTableHDU     32   371R x 7C   [K, D, D, D, D, D, D]

# %%
c3 = fits.open('code_outputs_IR/cigale_wit_IR_with_AGNs_results.fits')
c3.info()


cigale_ir_agn_ids = np.zeros((len(cat_z1_ids),))

cigale_ir_agn_mass = np.zeros((len(cat_z1_ids),))
cigale_ir_agn_sfr = np.zeros((len(cat_z1_ids),))
cigale_ir_agn_Av = np.zeros((len(cat_z1_ids),))

for i in range(len(cat_z1_ids)):
    temp = c3[1].data[i][0]
    
    cigale_ir_agn_ids[i] = temp
    cigale_ir_agn_mass[i] = c3[1].data[i][1]
    cigale_ir_agn_sfr[i] = c3[1].data[i][3]
    cigale_ir_agn_Av[i] = c3[1].data[i][5]
    
    
c3[1].header
c3.close()
# Out:
# Filename: code_outputs_IR/cigale_wit_IR_with_AGNs_results.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      16   (930,)   uint8
#   1  /data06/HELP/DATA/Denis_CANDELS/withIR_withAGNs/UVoptIR/results.f...  BinTableHDU     32   371R x 7C   [K, D, D, D, D, D, D]
